# %% [markdown]
# 1. Data structures are methods of organizing and storing data efficiently. They are important because they improve performance, simplify data management, and optimize memory usage.

# %% [markdown]
# 2. Mutable objects can be modified after creation (lists, dictionaries, sets). Immutable objects cannot be changed after creation (strings, tuples, integers).

# %% [markdown]
# 3. Lists are mutable and use square brackets, whereas tuples are immutable and use parentheses.

# %% [markdown]
# 4. Dictionaries store data as key-value pairs using a hash table for fast access.

# %% [markdown]
# 5. Sets automatically remove duplicates and provide faster membership testing.

# %% [markdown]
# 6. A string is an immutable sequence of characters, whereas a list is a mutable collection of elements.

# %% [markdown]
# 7. Since tuples are immutable, their values cannot be modified accidentally.

# %% [markdown]
# 8. A hash table stores key-value pairs and enables fast data retrieval. Python dictionaries use hash tables.

# %% [markdown]
# 9. Yes, lists can store elements of different data types.

# %% [markdown]
# 10. Immutability improves security, performance, and memory optimization.

# %% [markdown]
# 11. Dictionaries provide faster lookup using keys.

# %% [markdown]
# 12. Use tuples when data should remain unchanged, such as coordinates.

# %% [markdown]
# 13. Sets automatically remove duplicate values.

# %% [markdown]
# 14. In lists it searches values; in dictionaries it searches keys.

# %% [markdown]
# 15. No, tuples are immutable

# %% [markdown]
# 16. A dictionary containing another dictionary as a value.

# %% [markdown]
# 17. Average-case access time is O(1).

# %% [markdown]
# 18.Lists are preferred when ordered, mutable collections are required.

# %% [markdown]
# 19. Traditionally dictionaries had no fixed order; retrieval is based on keys, not position.

# %% [markdown]
# 20. Lists use indexes, while dictionaries use keys.

# %%
my_name="Kushal"
print(my_name)
# Out:
# Kushal

# %%
print(len("Hello World"))
# Out:
# 11

# %%
print("Python Programming"[:3])
# Out:
# Pyt

# %%
print("hello".upper())
# Out:
# HELLO

# %%
print("I like apple".replace("apple","orange"))
# Out:
# I like orange

# %%
nums=[1,2,3,4,5]
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst=[1,2,3,4]
lst.append(10)
print(lst)
# Out:
# [1, 2, 3, 4, 10]

# %%
lst=[1,2,3,4,5]
lst.remove(3)
print(lst)
# Out:
# [1, 2, 4, 5]

# %%
lst=['a','b','c','d']
print(lst[1])
# Out:
# b

# %%
lst=[10,20,30,40,50]
lst.reverse()
print(lst)
# Out:
# [50, 40, 30, 20, 10]

# %%
t=(100,200,300)
print(t)
# Out:
# (100, 200, 300)

# %%
t=('red','green','blue','yellow')
print(t[-2])
# Out:
# blue

# %%
print(min((10,20,5,15)))
# Out:
# 5

# %%
t=('dog','cat','rabbit')
print(t.index('cat'))
# Out:
# 1

# %%
fruits=('apple','banana','mango')
print('kiwi' in fruits)
# Out:
# False

# %%
s={'a','b','c'}
print(s)
# Out:
# {'c', 'b', 'a'}

# %%
s={1,2,3,4,5}
s.clear()
print(s)
# Out:
# set()

# %%
s={1,2,3,4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
print({1,2,3}.union({3,4,5}))
# Out:
# {1, 2, 3, 4, 5}

# %%
print({1,2,3}.intersection({2,3,4}))
# Out:
# {2, 3}

# %%
d={"name":"John","age":25,"city":"NY"}
print(d)
# Out:
# {'name': 'John', 'age': 25, 'city': 'NY'}

# %%
d={"name":"John","age":25}
d["country"]="USA"
print(d)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
d={"name":"Alice","age":30}
print(d["name"])
# Out:
# Alice

# %%
d={"name":"Bob","age":22,"city":"New York"}
d.pop("age")
print(d)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
d={"name":"Alice","city":"Paris"}
print("city" in d)
# Out:
# True

# %%
l=[1,2,3]; t=(4,5,6); d={"a":1}
print(l,t,d)
# Out:
# [1, 2, 3] (4, 5, 6) {'a': 1}

# %%
import random
lst=[random.randint(1,100) for _ in range(5)]
lst.sort()
print(lst)
# Out:
# [19, 50, 56, 59, 96]

# %%
lst=["a","b","c","d","e"]
print(lst[3])
# Out:
# d

# %%
d1={"a":1}; d2={"b":2}
print({**d1,**d2})
# Out:
# {'a': 1, 'b': 2}

# %%
lst=["apple","banana","apple"]
print(set(lst))
# Out:
# {'banana', 'apple'}
